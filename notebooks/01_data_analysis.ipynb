# %% [markdown]
# # 电商数据分析 - 基础探索
# ## 数据加载和初步分析
#
# 这个笔记本包含电商数据的加载、探索性分析和可视化。

# %%
# 导入必要的库
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os

# 添加src目录到路径
sys.path.append('./src')

# 设置中文字体
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

print("✅ 环境设置完成")

# %%
# 加载数据
from data_loader import load_sales_data, load_product_data, get_data_summary

sales_df = load_sales_data()
products_df = load_product_data()

# 显示数据摘要
summary = get_data_summary(sales_df, products_df)
print("📊 数据摘要:")
for key, value in summary.items():
    print(f"   {key}: {value}")

# %% [markdown]
# ## 下一步
# 继续在下一个单元格中进行数据探索和分析...
